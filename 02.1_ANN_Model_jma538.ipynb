# %%
#unhashtag this to install required libraries
#%pip install pandas numpy matplotlib scikit-learn seaborn shap

### CHOOSING LAYER ARCHITECTURE and CHANGED HUBER TO MSE###

import sys #System 
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import ops
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam    
from tensorflow.keras.metrics import Precision
from sklearn.preprocessing import StandardScaler
print(tf.__version__)
# Out:
# 2.16.2

# %%
#importing datasets
#Model Variables: Age, Bmi, Blood Glucose

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

target = "HbA1c_level"

#Making y DataFrame for the model
y_train = train[target].astype("float32").values
y_test  = test[target].astype("float32").values


#MINIMUM MODEL
train = train.drop(columns=["Unnamed: 0","former", "current", "ever", "never","no info", "not current", target, "male", "female", "other", "hypertension", "heart_disease", "diabetes"])
test = test.drop(columns=["Unnamed: 0","former", "current", "ever", "never", "no info", "not current", target, "male", "female", "other", "hypertension", "heart_disease", "diabetes"])


#Scaling continuous variables for easier use in model
#Binary columns are already created via preprocessing.
def separate_cols(x):
    bin_col = pd.DataFrame()
    cont_col = pd.DataFrame()
    for col in x.columns:
        if x[col].nunique() == 2:
            bin_col[col] = x[col].values
        else:
            cont_col[col] = x[col].values
    return bin_col, cont_col

train_bin, train_cont = separate_cols(train)
test_bin, test_cont = separate_cols(test)


from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#Scaling
scaled_tr = sc.fit_transform(train_cont)
scaled_te = sc.transform(test_cont)

#making dataframes for scaled sets
scaled_tr_cont = pd.DataFrame(scaled_tr, columns = train_cont.columns)
scaled_te_cont = pd.DataFrame(scaled_te, columns = test_cont.columns)

#Creating the independent variable datasets 
x_train = pd.concat([train_bin, scaled_tr_cont], axis = 1)
x_test = pd.concat([test_bin, scaled_te_cont], axis = 1)


#Checking dataframe to have all of the columns
print(x_train)
# Out:
#             age       bmi  blood_glucose_level
# 0      0.141014  2.521511             1.514969
# 1      0.141014  0.390141             0.486562
# 2      0.674635  0.403462             2.984121
# 3      1.697407 -0.447605             0.486562
# 4     -0.926226  0.829736             0.045817
# ...         ...       ...                  ...
# 76884  0.363356  1.198286            -0.296985
# 76885 -0.792821 -0.373600             0.413105
# 76886  0.808040  1.550554             0.511048
# 76887 -1.326441  0.000870             0.168246
# 76888 -1.815593 -1.800433             1.514969
#
# [76889 rows x 3 columns]

# %%
### Creating Sequential Model ###

model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(shape=(x_train.shape[1],)),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(15, activation="relu"),
        tf.keras.layers.Dense(1, activation="linear")
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 15)             │           975 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,247 (4.87 KB)
#  Trainable params: 1,247 (4.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compiling to create backpropigation, loss and metrics
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
#Call back used to prevent overfitting
early_stop= tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    verbose=1
)
callback = [early_stop, reduce_lr]
#Adam used as optimizer for backpropigation
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

#Huber loss function used in regression problems
model.compile(optimizer=optimizer, loss="mse", metrics=["mae", "mse", tf.keras.metrics.RootMeanSquaredError(name="rmse")])
ann = model.fit(x_train,y_train,batch_size=128, epochs=200, validation_split=0.2, callbacks=[callback])

###uncomment this when wanting to train another model
#ann2 = model.fit(x_train,y_train,batch_size=64, epochs=100, validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 22.9652 - mae: 4.5974 - mse: 22.9652 - rmse: 4.7922 - val_loss: 12.7124 - val_mae: 3.3210 - val_mse: 12.7124 - val_rmse: 3.5654 - learning_rate: 1.0000e-04
# Epoch 2/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.1457 - mae: 2.2999 - mse: 7.1457 - rmse: 2.6731 - val_loss: 3.9009 - val_mae: 1.6174 - val_mse: 3.9009 - val_rmse: 1.9751 - learning_rate: 1.0000e-04
# Epoch 3/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1052 - mae: 1.4258 - mse: 3.1052 - rmse: 1.7622 - val_loss: 2.6288 - val_mae: 1.3106 - val_mse: 2.6288 - val_rmse: 1.6214 - learning_rate: 1.0000e-04
# Epoch 4/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3019 - mae: 1.2248 - mse: 2.3019 - rmse: 1.5172 - val_loss: 2.0490 - val_mae: 1.1607 - val_mse: 2.0490 - val_rmse: 1.4314 - learning_rate: 1.0000e-04
# Epoch 5/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.8030 - mae: 1.0896 - mse: 1.8030 - rmse: 1.3428 - val_loss: 1.6243 - val_mae: 1.0410 - val_mse: 1.6243 - val_rmse: 1.2745 - learning_rate: 1.0000e-04
# Epoch 6/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4520 - mae: 0.9848 - mse: 1.4520 - rmse: 1.2050 - val_loss: 1.3503 - val_mae: 0.9553 - val_mse: 1.3503 - val_rmse: 1.1620 - learning_rate: 1.0000e-04
# Epoch 7/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.2450 - mae: 0.9217 - mse: 1.2450 - rmse: 1.1158 - val_loss: 1.2097 - val_mae: 0.9148 - val_mse: 1.2097 - val_rmse: 1.0999 - learning_rate: 1.0000e-04
# Epoch 8/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1524 - mae: 0.8930 - mse: 1.1524 - rmse: 1.0735 - val_loss: 1.1554 - val_mae: 0.8976 - val_mse: 1.1554 - val_rmse: 1.0749 - learning_rate: 1.0000e-04
# Epoch 9/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1164 - mae: 0.8803 - mse: 1.1164 - rmse: 1.0566 - val_loss: 1.1356 - val_mae: 0.8857 - val_mse: 1.1356 - val_rmse: 1.0656 - learning_rate: 1.0000e-04
# Epoch 10/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1015 - mae: 0.8746 - mse: 1.1015 - rmse: 1.0495 - val_loss: 1.1241 - val_mae: 0.8829 - val_mse: 1.1241 - val_rmse: 1.0602 - learning_rate: 1.0000e-04
# Epoch 11/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0936 - mae: 0.8719 - mse: 1.0936 - rmse: 1.0458 - val_loss: 1.1184 - val_mae: 0.8867 - val_mse: 1.1184 - val_rmse: 1.0576 - learning_rate: 1.0000e-04
# Epoch 12/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0880 - mae: 0.8711 - mse: 1.0880 - rmse: 1.0431 - val_loss: 1.1135 - val_mae: 0.8844 - val_mse: 1.1135 - val_rmse: 1.0552 - learning_rate: 1.0000e-04
# Epoch 13/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0842 - mae: 0.8701 - mse: 1.0842 - rmse: 1.0413 - val_loss: 1.1103 - val_mae: 0.8832 - val_mse: 1.1103 - val_rmse: 1.0537 - learning_rate: 1.0000e-04
# Epoch 14/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0820 - mae: 0.8703 - mse: 1.0820 - rmse: 1.0402 - val_loss: 1.1102 - val_mae: 0.8774 - val_mse: 1.1102 - val_rmse: 1.0537 - learning_rate: 1.0000e-04
# Epoch 15/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0800 - mae: 0.8697 - mse: 1.0800 - rmse: 1.0392 - val_loss: 1.1092 - val_mae: 0.8755 - val_mse: 1.1092 - val_rmse: 1.0532 - learning_rate: 1.0000e-04
# Epoch 16/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0788 - mae: 0.8696 - mse: 1.0788 - rmse: 1.0387 - val_loss: 1.1063 - val_mae: 0.8799 - val_mse: 1.1063 - val_rmse: 1.0518 - learning_rate: 1.0000e-04
# Epoch 17/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0778 - mae: 0.8695 - mse: 1.0778 - rmse: 1.0382 - val_loss: 1.1051 - val_mae: 0.8796 - val_mse: 1.1051 - val_rmse: 1.0512 - learning_rate: 1.0000e-04
# Epoch 18/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0771 - mae: 0.8695 - mse: 1.0771 - rmse: 1.0378 - val_loss: 1.1038 - val_mae: 0.8850 - val_mse: 1.1038 - val_rmse: 1.0506 - learning_rate: 1.0000e-04
# Epoch 19/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0763 - mae: 0.8695 - mse: 1.0763 - rmse: 1.0374 - val_loss: 1.1033 - val_mae: 0.8872 - val_mse: 1.1033 - val_rmse: 1.0504 - learning_rate: 1.0000e-04
# Epoch 20/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0755 - mae: 0.8697 - mse: 1.0755 - rmse: 1.0370 - val_loss: 1.1025 - val_mae: 0.8781 - val_mse: 1.1025 - val_rmse: 1.0500 - learning_rate: 1.0000e-04
# Epoch 21/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0749 - mae: 0.8693 - mse: 1.0749 - rmse: 1.0368 - val_loss: 1.1032 - val_mae: 0.8774 - val_mse: 1.1032 - val_rmse: 1.0503 - learning_rate: 1.0000e-04
# Epoch 22/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0744 - mae: 0.8691 - mse: 1.0744 - rmse: 1.0365 - val_loss: 1.1010 - val_mae: 0.8830 - val_mse: 1.1010 - val_rmse: 1.0493 - learning_rate: 1.0000e-04
# Epoch 23/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0740 - mae: 0.8689 - mse: 1.0740 - rmse: 1.0364 - val_loss: 1.1006 - val_mae: 0.8811 - val_mse: 1.1006 - val_rmse: 1.0491 - learning_rate: 1.0000e-04
# Epoch 24/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0735 - mae: 0.8691 - mse: 1.0735 - rmse: 1.0361 - val_loss: 1.1000 - val_mae: 0.8842 - val_mse: 1.1000 - val_rmse: 1.0488 - learning_rate: 1.0000e-04
# Epoch 25/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0729 - mae: 0.8691 - mse: 1.0729 - rmse: 1.0358 - val_loss: 1.0995 - val_mae: 0.8851 - val_mse: 1.0995 - val_rmse: 1.0486 - learning_rate: 1.0000e-04
# Epoch 26/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0727 - mae: 0.8689 - mse: 1.0727 - rmse: 1.0357 - val_loss: 1.0990 - val_mae: 0.8833 - val_mse: 1.0990 - val_rmse: 1.0483 - learning_rate: 1.0000e-04
# Epoch 27/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0724 - mae: 0.8689 - mse: 1.0724 - rmse: 1.0356 - val_loss: 1.0991 - val_mae: 0.8853 - val_mse: 1.0991 - val_rmse: 1.0484 - learning_rate: 1.0000e-04
# Epoch 28/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0724 - mae: 0.8691 - mse: 1.0724 - rmse: 1.0356 - val_loss: 1.1002 - val_mae: 0.8855 - val_mse: 1.1002 - val_rmse: 1.0489 - learning_rate: 1.0000e-04
# Epoch 29/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0723 - mae: 0.8693 - mse: 1.0723 - rmse: 1.0355 - val_loss: 1.1023 - val_mae: 0.8722 - val_mse: 1.1023 - val_rmse: 1.0499 - learning_rate: 1.0000e-04
# Epoch 30/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0720 - mae: 0.8683 - mse: 1.0720 - rmse: 1.0354 - val_loss: 1.0994 - val_mae: 0.8885 - val_mse: 1.0994 - val_rmse: 1.0485 - learning_rate: 1.0000e-04
# Epoch 31/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0718 - mae: 0.8691 - mse: 1.0718 - rmse: 1.0353 - val_loss: 1.0979 - val_mae: 0.8808 - val_mse: 1.0979 - val_rmse: 1.0478 - learning_rate: 1.0000e-04
# Epoch 32/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0716 - mae: 0.8689 - mse: 1.0716 - rmse: 1.0352 - val_loss: 1.0977 - val_mae: 0.8819 - val_mse: 1.0977 - val_rmse: 1.0477 - learning_rate: 1.0000e-04
# Epoch 33/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0714 - mae: 0.8689 - mse: 1.0714 - rmse: 1.0351 - val_loss: 1.0982 - val_mae: 0.8791 - val_mse: 1.0982 - val_rmse: 1.0480 - learning_rate: 1.0000e-04
# Epoch 34/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0716 - mae: 0.8687 - mse: 1.0716 - rmse: 1.0352 - val_loss: 1.0982 - val_mae: 0.8779 - val_mse: 1.0982 - val_rmse: 1.0479 - learning_rate: 1.0000e-04
# Epoch 35/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0712 - mae: 0.8688 - mse: 1.0712 - rmse: 1.0350 - val_loss: 1.0973 - val_mae: 0.8834 - val_mse: 1.0973 - val_rmse: 1.0475 - learning_rate: 1.0000e-04
# Epoch 36/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0710 - mae: 0.8686 - mse: 1.0710 - rmse: 1.0349 - val_loss: 1.1000 - val_mae: 0.8895 - val_mse: 1.1000 - val_rmse: 1.0488 - learning_rate: 1.0000e-04
# Epoch 37/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0707 - mae: 0.8690 - mse: 1.0707 - rmse: 1.0347 - val_loss: 1.0971 - val_mae: 0.8810 - val_mse: 1.0971 - val_rmse: 1.0474 - learning_rate: 1.0000e-04
# Epoch 38/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0708 - mae: 0.8686 - mse: 1.0708 - rmse: 1.0348 - val_loss: 1.0978 - val_mae: 0.8817 - val_mse: 1.0978 - val_rmse: 1.0477 - learning_rate: 1.0000e-04
# Epoch 39/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0705 - mae: 0.8687 - mse: 1.0705 - rmse: 1.0346 - val_loss: 1.0993 - val_mae: 0.8763 - val_mse: 1.0993 - val_rmse: 1.0485 - learning_rate: 1.0000e-04
# Epoch 40/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0705 - mae: 0.8685 - mse: 1.0705 - rmse: 1.0347 - val_loss: 1.0972 - val_mae: 0.8847 - val_mse: 1.0972 - val_rmse: 1.0475 - learning_rate: 1.0000e-04
# Epoch 41/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0707 - mae: 0.8684 - mse: 1.0707 - rmse: 1.0347 - val_loss: 1.0970 - val_mae: 0.8844 - val_mse: 1.0970 - val_rmse: 1.0474 - learning_rate: 1.0000e-04
# Epoch 42/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0706 - mae: 0.8690 - mse: 1.0706 - rmse: 1.0347 - val_loss: 1.0967 - val_mae: 0.8823 - val_mse: 1.0967 - val_rmse: 1.0472 - learning_rate: 1.0000e-04
# Epoch 43/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0702 - mae: 0.8686 - mse: 1.0702 - rmse: 1.0345 - val_loss: 1.0978 - val_mae: 0.8764 - val_mse: 1.0978 - val_rmse: 1.0477 - learning_rate: 1.0000e-04
# Epoch 44/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0701 - mae: 0.8687 - mse: 1.0701 - rmse: 1.0345 - val_loss: 1.0968 - val_mae: 0.8803 - val_mse: 1.0968 - val_rmse: 1.0473 - learning_rate: 1.0000e-04
# Epoch 45/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0701 - mae: 0.8684 - mse: 1.0701 - rmse: 1.0345 - val_loss: 1.0972 - val_mae: 0.8803 - val_mse: 1.0972 - val_rmse: 1.0475 - learning_rate: 1.0000e-04
# Epoch 46/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0699 - mae: 0.8684 - mse: 1.0699 - rmse: 1.0344 - val_loss: 1.0971 - val_mae: 0.8790 - val_mse: 1.0971 - val_rmse: 1.0474 - learning_rate: 1.0000e-04
# Epoch 47/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0700 - mae: 0.8685 - mse: 1.0700 - rmse: 1.0344 - val_loss: 1.0962 - val_mae: 0.8825 - val_mse: 1.0962 - val_rmse: 1.0470 - learning_rate: 1.0000e-04
# Epoch 48/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0698 - mae: 0.8688 - mse: 1.0698 - rmse: 1.0343 - val_loss: 1.0979 - val_mae: 0.8818 - val_mse: 1.0979 - val_rmse: 1.0478 - learning_rate: 1.0000e-04
# Epoch 49/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0702 - mae: 0.8682 - mse: 1.0702 - rmse: 1.0345 - val_loss: 1.0974 - val_mae: 0.8875 - val_mse: 1.0974 - val_rmse: 1.0476 - learning_rate: 1.0000e-04
# Epoch 50/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0700 - mae: 0.8691 - mse: 1.0700 - rmse: 1.0344 - val_loss: 1.0973 - val_mae: 0.8780 - val_mse: 1.0973 - val_rmse: 1.0475 - learning_rate: 1.0000e-04
# Epoch 51/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0698 - mae: 0.8685 - mse: 1.0698 - rmse: 1.0343 - val_loss: 1.0967 - val_mae: 0.8785 - val_mse: 1.0967 - val_rmse: 1.0472 - learning_rate: 1.0000e-04
# Epoch 52/200
# 450/481 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0777 - mae: 0.8702 - mse: 1.0777 - rmse: 1.0381
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0696 - mae: 0.8684 - mse: 1.0696 - rmse: 1.0342 - val_loss: 1.0961 - val_mae: 0.8824 - val_mse: 1.0961 - val_rmse: 1.0470 - learning_rate: 1.0000e-04
# Epoch 53/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0691 - mae: 0.8684 - mse: 1.0691 - rmse: 1.0340 - val_loss: 1.0962 - val_mae: 0.8824 - val_mse: 1.0962 - val_rmse: 1.0470 - learning_rate: 5.0000e-05
# Epoch 54/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0689 - mae: 0.8683 - mse: 1.0689 - rmse: 1.0339 - val_loss: 1.0963 - val_mae: 0.8797 - val_mse: 1.0963 - val_rmse: 1.0470 - learning_rate: 5.0000e-05
# Epoch 55/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0690 - mae: 0.8682 - mse: 1.0690 - rmse: 1.0339 - val_loss: 1.0966 - val_mae: 0.8842 - val_mse: 1.0966 - val_rmse: 1.0472 - learning_rate: 5.0000e-05
# Epoch 56/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0690 - mae: 0.8686 - mse: 1.0690 - rmse: 1.0339 - val_loss: 1.0962 - val_mae: 0.8796 - val_mse: 1.0962 - val_rmse: 1.0470 - learning_rate: 5.0000e-05
# Epoch 57/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0688 - mae: 0.8682 - mse: 1.0688 - rmse: 1.0338 - val_loss: 1.0959 - val_mae: 0.8829 - val_mse: 1.0959 - val_rmse: 1.0469 - learning_rate: 5.0000e-05
# Epoch 58/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0690 - mae: 0.8685 - mse: 1.0690 - rmse: 1.0339 - val_loss: 1.0967 - val_mae: 0.8773 - val_mse: 1.0967 - val_rmse: 1.0472 - learning_rate: 5.0000e-05
# Epoch 59/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0690 - mae: 0.8682 - mse: 1.0690 - rmse: 1.0339 - val_loss: 1.0959 - val_mae: 0.8831 - val_mse: 1.0959 - val_rmse: 1.0469 - learning_rate: 5.0000e-05
# Epoch 60/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0688 - mae: 0.8686 - mse: 1.0688 - rmse: 1.0338 - val_loss: 1.0965 - val_mae: 0.8780 - val_mse: 1.0965 - val_rmse: 1.0471 - learning_rate: 5.0000e-05
# Epoch 61/200
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0688 - mae: 0.8681 - mse: 1.0688 - rmse: 1.0338 - val_loss: 1.0960 - val_mae: 0.8804 - val_mse: 1.0960 - val_rmse: 1.0469 - learning_rate: 5.0000e-05
# Epoch 62/200
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0684 - mae: 0.8690 - mse: 1.0684 - rmse: 1.0336
# Epoch 62: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0688 - mae: 0.8682 - mse: 1.0688 - rmse: 1.0339 - val_loss: 1.0959 - val_mae: 0.8831 - val_mse: 1.0959 - val_rmse: 1.0469 - learning_rate: 5.0000e-05

# %%
#Importing matplotlib here to start creating plots 
import matplotlib.pyplot as plt

#prints both loss and val_loss to see whether or not the model is learning and/or overfitting
#NOTE: If lines are close together, it means model is generalizing well since curve isn't deviating from the trained model.
plt.plot(ann.history['loss'], label='train loss')
plt.plot(ann.history['val_loss'], label='val loss')
plt.legend(); plt.title("3 Hidden layers: 128, 64, 32"); plt.xlabel('epoch'); plt.ylabel('Loss'); plt.show()

# %%
#Testing the data
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

y_pred = model.predict(x_test,verbose=0).squeeze()

y_pred_df = pd.DataFrame({"y prediction": y_pred})
y_test_df = pd.DataFrame({"y actual": y_test})
predictions = pd.concat([y_pred_df, y_test_df], axis=1)
print(predictions)
#print(y_test)


loss, mae, mse, rmse = model.evaluate(x_test, y_test, verbose=1)

y_mean = np.full_like(y_test, y_test.mean(), dtype=float)
y_median = np.full_like(y_test, np.median(y_test), dtype=float)
mse_mean = mean_squared_error(y_test, y_mean)
mse_median = mean_squared_error(y_test, y_median)

improve_vs_mean = (1 - mse/mse_mean) if mse_mean > 0 else np.nan
improve_vs_median = (1 - mse/mse_median) if mse_median > 0 else np.nan


print(f"|Test Dataset loss: {loss:.4f} |Test MAE: {mae:.4f} |Test RMSE: {rmse:.4f}|\n")
print("Baseline (mean) mse:", mse_mean)
print("Baseline (median) mse:", mse_median)
print("Improvement vs Mean:", improve_vs_mean)
print("Improvement vs Median:", improve_vs_median)
# Out:
#        y prediction  y actual
# 0          5.371105       6.6
# 1          5.527825       4.8
# 2          5.472304       5.0
# 3          5.401516       6.1
# 4          5.410578       6.1
# ...             ...       ...
# 19218      5.481506       4.0
# 19219      6.343616       6.2
# 19220      5.310759       5.8
# 19221      5.434681       6.0
# 19222      5.321142       6.5
#
# [19223 rows x 2 columns]
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0863 - mae: 0.8770 - mse: 1.0863 - rmse: 1.0423
# |Test Dataset loss: 1.0863 |Test MAE: 0.8770 |Test RMSE: 1.0423|
#
# Baseline (mean) mse: 1.1587101512500375
# Baseline (median) mse: 1.2307054562865167
# Improvement vs Mean: 0.06250107167859487
# Improvement vs Median: 0.11734402453226167

# %%
# Histogram with density
plt.hist(predictions, alpha=0.5, color=["orange", "blue"])
plt.legend(predictions)

# Plot a line through the histogram (midpoints vs density)
plt.xlabel("HbA1c levels")
plt.ylabel("Density")
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import r2_score
# Compute correlation (R² and Pearson's r) to test the correlation between the Actual hba1c and Predicted hba1c
#These variables are to be used in the title
r2 = r2_score(y_test, y_pred)
corr = np.corrcoef(y_test, y_pred)[0,1]

# Plot correlation scatter
plt.figure(figsize=(7,7))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, edgecolor=None)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # perfect prediction line

#Adding the lables to make the graph understandable.
plt.xlabel("Actual HbA1c (y_test)")
plt.ylabel("Predicted HbA1c (y_pred)")
plt.title(f"Prediction vs Actual\nR² = {r2:.3f}, Correlation = {corr:.3f}")
plt.grid(True)
plt.show()

# %%
#Regression plot is used as another means to 
y_pred = y_pred.flatten()

# Compute R²
r2 = r2_score(y_test, y_pred)

plt.figure(figsize=(9,6))
sns.regplot(x=y_test, y=y_pred, scatter_kws={'alpha':0.5}, line_kws={"color":"red"})

plt.xlabel("Actual HbA1c (y_test)")
plt.ylabel("Predicted HbA1c (y_pred)")
plt.title(f"Regression Plot (R² = {r2:.3f})")

plt.show()

# %%
#Using shap to test feature importance in our dataset.

import shap


#explainer = shap.Explainer(model, x_train)
#shap_values = explainer(x_test)
# Summary plot (feature importance as beeswarm)
#shap.summary_plot(shap_values, x_test, feature_names=x_test.columns)

# Bar plot of average absolute importance
#shap.summary_plot(shap_values, x_test, feature_names=x_test.columns, plot_type="bar")

# %%
#print(x_test)
#print(y_test_df)

# %%
#Writing predictions into csv

#predictions.to_csv("prediction_continuous.csv", index=False)

#pd.DataFrame(ann.history).to_csv("training_hba1c.csv", index=False)

# %%
#from sklearn.linear_model import LinearRegression
#reg = LinearRegression().fit(x_train, y_train)
#print("Baseline R^2 (train):", reg.score(x_train, y_train))
#print("Baseline R^2 (test):", reg.score(x_test, y_test))
